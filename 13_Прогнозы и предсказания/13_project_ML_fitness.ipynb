# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных." data-toc-modified-id="Обзор-данных.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Исследовательский-анализ-данных-(EDA)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Распределение-признаков-ушедших-клиентов-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Распределение-признаков-ушедших-клиентов-и-тех,-кто-остался-(не-попали-в-отток)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Распределение признаков ушедших клиентов и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Матрица-корреляции" data-toc-modified-id="Матрица-корреляции-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Матрица корреляции</a></span></li></ul></li><li><span><a href="#Модель-прогнозирования-оттока-пользователей" data-toc-modified-id="Модель-прогнозирования-оттока-пользователей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель прогнозирования оттока пользователей</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Кластеризация-пользователей" data-toc-modified-id="Кластеризация-пользователей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Кластеризация пользователей</a></span><ul class="toc-item"><li><span><a href="#Построение-матрицы-расстояний" data-toc-modified-id="Построение-матрицы-расстояний-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Построение матрицы расстояний</a></span></li><li><span><a href="#Распределение-признаков-для-кластеров" data-toc-modified-id="Распределение-признаков-для-кластеров-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Распределение признаков для кластеров</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Выводы-и-рекомендации-по-работе-с-клиентами-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Выводы и рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# # Прогнозирование оттока клиентов сети фитнес-центров  <a class="tocSkip">
#
#
#
# ## Описание проекта. <a class="tocSkip">
#
# Сеть фитнес-центров разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал.
#
#
#
# ###### Цель исследования :
# Провести анализ и подготовить план действий по удержанию клиентов.
# А именно:
#
#  - Научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
#  - Сформировать типичные портреты пользователей: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
#  - Проанализировать основные признаки, наиболее сильно влияющие на отток;
#  - Сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#
#  	1) выделить целевые группы клиентов;
#
#  	2) предложить меры по снижению оттока;
#
#  	3) определить другие особенности взаимодействия с клиентами.
#
#
# ###### Ход исследования
#
# Отдел по работе с клиентами перевёл в электронный вид множество анкет пользователей.предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц
# Данные предоставлены в файле : /datasets/gym_churn.csv
#
# О качестве данных ничего не известно. Поэтому перед проверкой гипотез понадобится обзор данных.
#
# Проверим данные на ошибки и оценим их влияние на исследование. Затем, на этапе предобработки поищем возможность исправить самые критичные ошибки данных.
#
#
# Таким образом, исследование пройдёт в пять этапов:
#
#
# [**1. Обзор данных.**](#1-bullet)
#
#
# [**2. Предобработка данных**](#2-bullet)
#
#
# [**3. Исследовательский анализ данных (EDA)**](#3-bullet)
#
# - [**3.1 Распределение признаков ушедших клиентов и тех, кто остался (не попали в отток)**](#31-bullet)
# - [**3.2 Матрица корреляции**](#32-bullet)
#
#
# [**4. Модель прогнозирования оттока пользователей**](#4-bullet)
#
# - [**4.1 Логистическая регрессия**](#41-bullet)
# - [**4.2 Случайный лес**](#42-bullet)
#
# [**5. Кластеризация пользователей**](#5-bullet)
#
# - [**5.1 Построение матрицы расстояний**](#51-bullet)
# - [**5.2 Распределение признаков для кластеров**](#52-bullet)
#
#
# [**6. Выводы и рекомендации по работе с клиентами**](#6-bullet)

# %% [markdown]
# <a id="1-bullet"></a>
# ## Обзор данных.

# %%
#импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from plotly import graph_objects as go
import datetime as dt
import numpy as np
from math import floor
import math as mth
from scipy import stats as st
import warnings

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from sklearn.metrics import roc_auc_score

# %%
#убираем системные предупреждения
warnings.filterwarnings('ignore')
#настраиваем отображение колонок (полностью)
pd.set_option('display.max_columns', None)

# %%
#открываем и сохраняем как датафрейм файл с данными:
try:
    # personal path
    df = pd.read_csv('gym_churn.csv')  
except:
    # Yandex path
    df = pd.read_csv('/datasets/gym_churn.csv')

# %% [markdown]
# Для удобства зададим несколько функций:

# %%
#функция для вывода состава столбцов
def describe_cols(df_data):
    df = df_data
    values = pd.DataFrame()
    
    for col in df.columns:
        values[col] = [df[col].unique(), df[col].dtypes, df[col].nunique()]
        
    return values.transpose().sort_values(by=1, ascending=True).rename(
        {0: 'Значения', 1: 'тип данных', 2: 'Кол-во уникальных значений'}, axis=1)


#функция для вывода пустых значений и их доли в столбцах датафрейма
def nan_values(df_data):
    df = df_data
    count_missing = df.isna().sum()
    percent_missing = round(df.isna().sum() * 100 / len(df), 2)
    
    missing_value_df = pd.DataFrame({'column_name': df.columns,
                                     'num_missing': count_missing,
                                     'percent_missing': percent_missing})
    
    return missing_value_df


#функция для вывода информации о файле
def df_info (df_data):
    print('Количество строк файла:', len(df_data))
    print()
    print('Информация о содержимом файла:')
    display(describe_cols(df_data))
    print()
    print('Информация о пропусках данных:')
    display(nan_values(df_data))
    print()
    print('Первые пять строк таблицы:')
    display(df_data.head())

#просмотр данных столбца: уникальные значения, тип данных, кол-во пропусков
def preprocessing(column):
    #print(column, '-', dict_name[column])
    print('тип данных', df[column].dtypes)
    print('количество пропусков',df[column].isna().sum())
    if df[column].dtypes != 'object':
        print('минимальное значение:',df[column].min(), 'максимальное значение:', df[column].max() )
    print('уникальные значения:', '\n', df[column].value_counts())

# %% [markdown]
# Рассмотрим подробнее содержимое файла:

# %%
df_info(df)
# Out:
# Количество строк файла: 4000
#
# Информация о содержимом файла:
#                                                                             Значения  \
# gender                                                                        [1, 0]
# Near_Location                                                                 [1, 0]
# Partner                                                                       [1, 0]
# Promo_friends                                                                 [1, 0]
# Phone                                                                         [0, 1]
# Contract_period                                                           [6, 12, 1]
# Group_visits                                                                  [1, 0]
# Age                                [29, 31, 28, 33, 26, 34, 32, 30, 23, 27, 35, 2...
# Lifetime                           [3, 7, 2, 0, 1, 11, 4, 8, 14, 6, 5, 15, 12, 21...
# ...

# %% [markdown]
# **Вывод по разделу 1**
#
# В представленном для анализа файле 4000 строк с данными анкет клиентов фитнес-центра.
#
# Таблица содержит 14 столбцов:
#
# •	Данные пользователя за предыдущий до проверки факта оттока месяц:
#  -	`Gender` — пол  (1 - женщины, 0 - мужчины)
#  -	`Near_Location` — проживание или работа в районе, где находится фитнес-центр
#  -	`Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента)
#  -	`Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента)
#  -	`Phone` — наличие контактного телефона
#  -	`Age` — возраст
#  -	`Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах)
#
# •	Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#  -	`Contract_period` — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год)
#  -	`Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах)
#  -	`Group_visits` — факт посещения групповых занятий
#  -	`Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента
#  -	`Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц
#  -	`Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон
#
#
# Пропуски отсутствуют.
#
# Предварительно можно утверждать, что, данных достаточно для анализа.
#
# На этапе предобработки внесем следующие изменения:
#
# - Исправим нарушения стиля (заменим прописные буквы в наименованиях столбцов на строчные)
# - Данные столбца `Month_to_end_contract` переведем из float в int
#
# А также проверим данные на дубликаты.

# %% [markdown]
# <a id="2-bullet"></a>
# ## Предобработка данных

# %% [markdown]
# Заменим регистр наименования колонок:

# %%
#замена регистра 
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'month_to_end_contract', 'lifetime',
#        'avg_class_frequency_total', 'avg_class_frequency_current_month',
#        'churn'],
#       dtype='object')

# %% [markdown]
# Приведем данные столбца `month_to_end_contract` к типу данных INT:

# %%
df['month_to_end_contract'] = df['month_to_end_contract'].astype('int')

# %% [markdown]
# Проверим данные на дубликаты:

# %%
#подсчет дубликатов
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим внесение изменений:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   int32
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# **Вывод по разделу 2**
#
# В процессе предобработки данных была произведена замена регистра наименований столбцов, тип данных столбца month_to_end_contract приведен к типу данных int.
#
# Дубликаты отсутствуют.
# Данные готовы к анализу.

# %% [markdown]
# <a id="3-bullet"></a>
# ## Исследовательский анализ данных (EDA)

# %% [markdown]
# Посмотрим на наш датасет:

# %%
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# **Вывод**
#
# Мы видим, что в фитнес-центре почти поровну мужчин и женщин (женщин больше на 1%), подавляющее большинство которых живут или работают рядом со спортзалом и пришли в спортзал по собственной инициативе (не по акции).
#
# 90% предоставляют данные своих телефонов.
#
# Действующий контракт : у медианного большинства на 1 месяц, только у 25% он на 6-12 месяцев. Срок до окончания текущего действующего абонемента у большинства клиентов - 1 месяц, у 25% -6-12 месяцев.
#
# Более 50% клиентов пришли в спортзал не более 3 месяцев назад,  25% ходят в спортзал от  5 до 31 месяца в среднем 1-2 раза в неделю.
#
# Медианный возраст клиента- 29 лет, только у 25% от 31 до 41 года.
#
# суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон- в среднем 147у.е.

# %% [markdown]
# <a id="31-bullet"></a>
# ### Распределение признаков ушедших клиентов и тех, кто остался (не попали в отток)

# %% [markdown]
# Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался:

# %%
#функция для выделения цветом ячеек с максимальным значением
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: lightblue' if v else '' for v in is_max]

# %%
#группируем признаки по оставшимся и ушедшим клиентам 
df.groupby('churn').agg('mean').T.style.apply(highlight_max, axis = 1)
# Out:
# <style type="text/css">
# #T_91eb0_row0_col1, #T_91eb0_row1_col0, #T_91eb0_row2_col0, #T_91eb0_row3_col0, #T_91eb0_row4_col0, #T_91eb0_row5_col0, #T_91eb0_row6_col0, #T_91eb0_row7_col0, #T_91eb0_row8_col0, #T_91eb0_row9_col0, #T_91eb0_row10_col0, #T_91eb0_row11_col0, #T_91eb0_row12_col0 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_91eb0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >churn</th>
#       <th id="T_91eb0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_91eb0_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91eb0_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_91eb0_row0_col0" class="data row0 col0" >0.510037</td>
#       <td id="T_91eb0_row0_col1" class="data row0 col1" >0.510839</td>
#     </tr>
#     <tr>
#       <th id="T_91eb0_level0_row1" class="row_heading level0 row1" >near_location</th>
# ...

# %% [markdown]
# Посмотрим на распределение признаков между ушедшими и оставшимия клиентами:

# %% [markdown]
# Графики распределения для дискретных величин:

# %%
for column in [
    'gender', 'near_location', 'partner', 'promo_friends', 'phone', 
    'group_visits', 'contract_period', 'lifetime', 'month_to_end_contract', 'age'
]:
    plt.figure(figsize=(8,5))
    ax = sns.countplot(data=df, x = df[column], hue='churn', saturation=1)
    ax.set_title('Распределение по признаку '  +column, fontsize = 16, color = 'black')
    plt.ylabel('Количество посетителей', fontsize = 14, color = 'black')
    plt.xlabel(column, fontsize = 14, color = 'black')
    ax.legend(['No churn', 'Churn'], loc=1, fontsize = 12)
plt.show()

# %% [markdown]
# Распределение непрерывных величин:

# %%
column_name = ['avg_additional_charges_total', 'avg_class_frequency_total', 'avg_class_frequency_current_month']

sns.set_theme(style="darkgrid")
for name in column_name:
    print('Распределение по признаку ', name)
    sns.displot(
        df, x=name, col="churn", hue='churn',kde=True,
        binwidth=1, height=5, #facet_kws=dict(margin_titles=True),
        );
    
    plt.show()
# Out:
# Распределение по признаку  avg_additional_charges_total
# Распределение по признаку  avg_class_frequency_total
# Распределение по признаку  avg_class_frequency_current_month

# %% [markdown]
# **Вывод**
#
# При делении клиентов на группы ушедших и оставшихся можно заметить, что средние значения признаков тех, кто попал в отток- либо ниже, либо почти равны значениям тех ,кто остался. У ушедших меньше возраст, меньше срок абонемента и частота посещения, они меньше тратят на дополнительные услуги.
#
# Верно и обратное: Чем дольше и чаще клиент посещает спортзал, чем больше срок его абонемента - тем ниже отток
# Можно сказать, что срок оплаченного абонемента- гарантия лояльности клиента как минимум до конца его действия. Это же можно сказать о клиентах, пришедших в фитнес-клуб от партнеров (их сотрудники, пользующиеся дополнительными льготами и скидками)- отток в этой группе также меньше.

# %% [markdown]
# <a id="32-bullet"></a>
# ### Матрица корреляции

# %% [markdown]
# Построим матрицу корреляции признаков:

# %%
#построим и отрисуем матрицу корреляций
cm = df.corr() #вычисляем матрицу корреляций

plt.figure(figsize=(15,15))
#нарисуем тепловую карту с подписями для матрицы корреляций
sns.heatmap(cm, annot=True, square=True)
ax.set_ylim(
    7, 0
)  # корректировка "рваных" полей heatmap в последней версии библиотеки
plt.show()

# %% [markdown]
# Мы видим признаки мультиколлинеарности:
# у пары contract_period - month_to_end_contract коэффициент корреляции составляет 97%, у пары avg_class_frequency_current_month - avg_class_frequency_total 95%.
#
# Удалим по одному из парных коррелирующих признаков:
# - month_to_end_contract
# - avg_class_frequency_total

# %%
#удаляем столбцы
df.drop(columns = ['month_to_end_contract', 'avg_class_frequency_total'], axis = 1, inplace = True) 
#проверяем удаление
df.columns
# Out:
# Index(['gender', 'near_location', 'partner', 'promo_friends', 'phone',
#        'contract_period', 'group_visits', 'age',
#        'avg_additional_charges_total', 'lifetime',
#        'avg_class_frequency_current_month', 'churn'],
#       dtype='object')

# %% [markdown]
# **Вывод**
#
# Во избежание мультиколлинеарности удалены признаки с высокой корреляцией друг к другу (один из каждой пары): month_to_end_contract и avg_class_frequency_total

# %% [markdown]
# **Вывод по разделу 3**
#
# Мы видим, что в фитнес-центре почти поровну мужчин и женщин (женщин больше на 1%), подавляющее большинство которых живут или работают рядом со спортзалом и пришли в спортзал по собственной инициативе (не по акции).
#
# 90% предоставляют данные своих телефонов.
#
# Действующий контракт : у медианного большинства на 1 месяц, только у 25% он на 6-12 месяцев. Срок до окончания текущего действующего абонемента у большинства клиентов - 1 месяц, у 25% -6-12 месяцев.
#
# Более 50% клиентов пришли в спортзал не более 3 месяцев назад, 25% ходят в спортзал от 5 до 31 месяца в среднем 1-2 раза в неделю.
#
# Медианный возраст клиента- 29 лет, только у 25% от 31 до 41 года.
#
# суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон- в среднем 147у.е.
#
#
# При делении клиентов на группы ушедших и оставшихся можно заметить, что у ушедших меньше возраст, меньше срок абонемента и частота посещения, они меньше тратят на дополнительные услуги.
#
# Верно и обратное: Чем дольше и чаще клиент посещает спортзал, чем больше срок его абонемента - тем ниже отток
# Можно сказать, что срок оплаченного абонемента- гарантия лояльности клиента как минимум до конца его действия. Это же можно сказать о клиентах, пришедших в фитнес-клуб от партнеров (их сотрудники, пользующиеся дополнительными льготами и скидками)- отток в этой группе также меньше.
#
# Во избежание мультиколлинеарности удалены признаки с высокой корреляцией друг к другу (один из каждой пары): month_to_end_contract и avg_class_frequency_total

# %% [markdown]
# <a id="4-bullet"></a>
# ## Модель прогнозирования оттока пользователей

# %% [markdown]
# Исходя из данных наш тип задачи- обучение с учителем, бинарная классификация. Построим модель прогнозирования оттока пользователей методами логистической регрессии и случайный лес.
#
# Подготовим данные: выделим целевую переменную и матрицу признаков, поделим выборку на обучающую и валидационную:

# %%
#готовим данные: отделяем целевую переменную и матрицу значений
X = df.drop('churn', axis = 1) # матрица объекты-признаки
y = df['churn'] #вектор с целевой переменной

# %%
#делим выборку на обучающую и валидационную  в пропорции 80:20.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <a id="41-bullet"></a>
# ### Логистическая регрессия

# %%
#задаем алгоритм для нашей модели
model = LogisticRegression(solver='liblinear', random_state=0)

# обучаем модель
model.fit(X_train, y_train)

#делаем прогнозы обученной моделью
lr_predictions = model.predict(X_test)
lr_probabilities = model.predict_proba(X_test)[:, 1]

# %% [markdown]
# Оценим метрики accuracy, precision и recall на валидационной выборке.

# %%
print('Размер датасета:', df.shape)
df.head()

# посмотрим, как соотносятся классы набора данных
print('Соотношение классов:\n', df['churn'].value_counts())
# Out:
# Размер датасета: (4000, 12)
# Соотношение классов:
#  0    2939
# 1    1061
# Name: churn, dtype: int64

# %% [markdown]
# Поскольку Accuracy работает только на сбалансированных выборках, а у нас явный перекос в соотношении классов, посчитаем сразу три метрики:

# %%
print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, lr_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, lr_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, lr_predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.90
# Precision: 0.79
# Recall: 0.79

# %% [markdown]
# Исходя из полученного значения метрики Accuracy мы правильно прогнозируем 90% ответов. Но Precision и Recall несколько ниже: обе по 0.79. Посмотрим, какие результаты даст второй алгоритм.

# %% [markdown]
# <a id="42-bullet"></a>
# ### Случайный лес

# %% [markdown]
# Перед обучением модели проведем стандартизацию данных:

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# Зададим алгоритм для модели, обучим ее и сделаем прогноз:

# %%
# зададим алгоритм для новой модели на основе алгоритма случайного леса
rf_model = RandomForestClassifier(n_estimators = 100, random_state=False) # Ваш код здесь
# обучим модель случайного леса
rf_model.fit(X_train_st, y_train)
# воспользуемся уже обученной моделью, чтобы сделать прогнозы
rf_predictions = rf_model.predict(X_test_st)# Ваш код здесь
rf_probabilities = rf_model.predict_proba(X_test_st)[:, 1] # Ваш код здесь

# %%
print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.90
# Precision: 0.81
# Recall: 0.75

# %% [markdown]
# Значения метрик при использовании моделей логистической регрессии и случайного леса сопоставимы друг с другом. Чтобы принять решение, рассчитаем для обоих моделей метрику вероятности ROC_AUC:

# %%
print('ROC_AUC для LogisticRegression: {:.2f}'.format(roc_auc_score(y_test, lr_probabilities) ))
print('ROC_AUC для RandomForestClassifier: {:.2f}'.format(roc_auc_score(y_test, rf_probabilities) ))
# Out:
# ROC_AUC для LogisticRegression: 0.96
# ROC_AUC для RandomForestClassifier: 0.95

# %% [markdown]
# Незначительно, но все же на 1% больше значение метрики у модели логистической регрессии.

# %% [markdown]
# **Вывод**
#
# Случайный лес дал такое же значение Accuracy в  90%. Но Precision составила 0,81, а Recall 0,75

# %% [markdown]
# **Вывод по разделу 4**
#
# При построении модели прогноза оттока пользователей оба алгоритма - логистическая регрессия и случайный лес -дали похожий результат. По совокупности метрик несколько лучше показала себя модель логистической регрессии.

# %% [markdown]
# <a id="5-bullet"></a>
# ## Кластеризация пользователей

# %% [markdown]
# <a id="51-bullet"></a>
# ### Построение матрицы расстояний

# %% [markdown]
# Для начала построим матрицу расстояний и нарисуем дендрограмму.

# %% [markdown]
# Стандартизируем данные:

# %%
sc = StandardScaler()
x_sc = sc.fit_transform(df)

# %% [markdown]
# Строим матрицу расстояний на стандартизованной матрице признаков:

# %%
linked = linkage(x_sc, method = 'ward')

# %% [markdown]
# Рисуем дендрограмму:

# %%
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Hierarchial clustering for GYM')
plt.show()

# %% [markdown]
#  На основании полученного графика можно предположить, что кластеров должно быть 5

# %% [markdown]
# **Вывод**
#
# На основании дендрограммы предполагаем, что количество кластеров должно быть равным 5.

# %% [markdown]
# <a id="52-bullet"></a>
# ### Распределение признаков для кластеров

# %% [markdown]
# Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов. За число кластеров примем n=5.

# %%
# задаём модель k_means с числом кластеров 3 и фиксируем значение random_state
km = KMeans(n_clusters=5, random_state=0)
# прогнозируем кластеры для наблюдений (алгоритм присваивает им номера от 0 до 2)
labels = km.fit_predict(x_sc)
# сохраняем метки кластера в поле нашего датасета
df['cluster_km'] = labels

# выводим статистику по средним значениям наших признаков по кластеру
display(df.groupby('cluster_km').mean().T.style.apply(highlight_max, axis = 1))
# Out:
# <style type="text/css">
# #T_f17d4_row0_col2, #T_f17d4_row1_col4, #T_f17d4_row2_col3, #T_f17d4_row3_col3, #T_f17d4_row4_col0, #T_f17d4_row4_col1, #T_f17d4_row4_col3, #T_f17d4_row4_col4, #T_f17d4_row5_col3, #T_f17d4_row6_col3, #T_f17d4_row7_col1, #T_f17d4_row8_col1, #T_f17d4_row9_col1, #T_f17d4_row10_col1, #T_f17d4_row11_col4 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_f17d4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cluster_km</th>
#       <th id="T_f17d4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f17d4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f17d4_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f17d4_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f17d4_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f17d4_level0_row0" class="row_heading level0 row0" >gender</th>
# ...

# %% [markdown]
# ПО средним значениям признаков можно сделать следующие выводы:
#
# Мы видим, что максимальное значение оттока клиентов 99,3% - в 4 кластере. Для него характернен контракт на 1-2 месяца, возраст 26-27 лет, самый маленький срок посещения фитнес-центра в 1 месяц  и самая низкая частота посещений - 1 раз в неделю, минимальная выручка от прочих услуг фитнес-центра
#
# Самые лояльные- с оттоком менее 1%- клиенты 1 и 3 кластеров: для них характерен абонемент на посещение финтес-центра сроком от 3 месяцев и выше, возраст около 30 лет, максимальный срок посещения - самый высокий по кластерам и в среднем он составляет 4-5 месяцев,  выручка от прочих услуг фитнес-центра также максимальна (в среднем 2 у.е.)

# %% [markdown]
# Построим графики распределения признаков в разрезе кластеров:

# %%
for column in [
    'gender', 'near_location', 'partner', 'promo_friends', 'phone', 
    'group_visits', 'contract_period'
]:
    plt.figure(figsize=(8,5))
    sns.set_style(style="whitegrid")
    ax = sns.countplot(data=df, x = df[column], hue='cluster_km', saturation=1)
    ax.set_title('Распределение по признаку '  +column, fontsize = 16, color = 'black')
    plt.ylabel('Количество посетителей', fontsize = 14, color = 'black')
    plt.xlabel(column, fontsize = 14, color = 'black')
    
plt.show()

# %%
for column in ['age', 'avg_additional_charges_total', 'lifetime', 'avg_class_frequency_current_month']:
    print(f'Распределение кластеров по признаку {column} ')
    sns.boxplot(x = 'cluster_km', y = df[column], data = df)
    plt.show()
# Out:
# Распределение кластеров по признаку age
# Распределение кластеров по признаку avg_additional_charges_total
# Распределение кластеров по признаку lifetime
# Распределение кластеров по признаку avg_class_frequency_current_month

# %% [markdown]
# **Вывод**
#
# Графики распределения также подтвердили наше предположение,  что клиенты кластера с максимальным оттоком клиентов (4 кластер)  отличаются коротким периодом контракта (1 месяц), самой низкой частотой посещения (раз в неделю), самым молодым возрастом, а также самыми низкими затратами на дополнительные услуги фитнес-центра.
#
# С другой стороны, кластеры с наибольшим количеством постоянных клиентов (1 и 3 кластер) показывают контракты на 6-12 месяцев. При этом клиенты 1-го кластера пришли в финтес-центр сами, а клиенты 3-го кластера -по промоакции "приведи друга" либо от компании-партнера, чьи сотрудники могут получать скидки на абонемент.
# у обоих самая высокая частота посещений (более 2 в медиане), самый высокий лайфтайм , расходы на доп услуги и возраст выше, чем в группе оттока.

# %% [markdown]
# **Вывод по разделу 5**
#
# На основании построенной матрицы расстояний и отрисованной дендрограммы мы определили оптимальное количество кластеров, равное 5, и построили модель кластеризации на основании алгоритма K-Means.
#
# Средние значения признаков для кластеров и распределение признаков по кластерам говорят о том,  что клиенты кластера с максимальным оттоком клиентов (4 кластер)  отличаются коротким периодом контракта (1 месяц), самой низкой частотой посещения (раз в неделю), самым молодым возрастом, а также самыми низкими затратами на дополнительные услуги фитнес-центра.
#
# Кластеры с наибольшим количеством постоянных клиентов (1 и 3 кластер) показывают контракты на 6-12 месяцев. При этом клиенты 1-го кластера пришли в финтес-центр сами, а клиенты 3-го кластера -по промоакции "приведи друга" либо от компании-партнера, чьи сотрудники могут получать скидки на абонемент.
# у обоих самая высокая частота посещений (более 2 в медиане), самый высокий лайфтайм , расходы на доп услуги и возраст выше, чем в группе оттока.

# %% [markdown]
# <a id="6-bullet"></a>
# ## Выводы и рекомендации по работе с клиентами

# %% [markdown]
# В представленном для анализа файле 4000 строк с данными анкет клиентов фитнес-центра.
#
# В процессе предобработки данных была произведена замена регистра наименований столбцов, тип данных столбца month_to_end_contract приведен к типу данных int.
#
# **Результаты исследования:**
#
# 1. Общая картина, характеризующая клиентов:
#
#   - В представленных данных  почти поровну мужчин и женщин (женщин больше на 1%), подавляющее большинство которых живут или работают рядом со спортзалом и пришли в спортзал по собственной инициативе (не по акции).
#
#   - Действующий контракт : у медианного большинства на 1 месяц, только у 25% он на 6-12 месяцев. Срок до окончания текущего действующего абонемента у большинства клиентов - 1 месяц, у 25% -6-12 месяцев.
#
#   - Более 50% клиентов пришли в спортзал не более 3 месяцев назад, 25% ходят в спортзал от 5 до 31 месяца в среднем 1-2 раза в неделю.
#
#   - Медианный возраст клиента- 29 лет, только у 25% возраст от 31 до 41 года.
#
#   - Суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон- в среднем 147у.е.
#
#
# 2. Возможность использования модели для предсказания оттока:  модель логистической регрессии.
#
#
# 3. Признаки клиентов, потенциально формирующих группу оттока:
#
# - данная категория клиентов отличаются коротким периодом контракта (1 месяц), самой низкой частотой посещения (раз в неделю), самым молодым возрастом (18-26 лет), а также самыми низкими затратами на дополнительные услуги фитнес-центра.
#
# 4. Признаки лояльности клиентов:
#
# - Чем дольше и чаще клиент посещает спортзал, чем больше срок его абонемента - тем больше вероятность, что он останется в фитнес-центре. Можно сказать, что срок оплаченного абонемента- гарантия лояльности клиента как минимум до конца его действия. Это же можно сказать о клиентах, пришедших в фитнес-клуб от партнеров (их сотрудники, пользующиеся дополнительными льготами и скидками)- отток в этой группе также меньше, а срок контракта составляет 6-12 месяцев.
# - высокая частота посещений (более 2 в медиане),
# - высокий лайфтайм (чем дольше клиент посещает фитнес-центр- тем больше его лояльность и вероятность продления абонемента на дальнейший период)
# - средний возраст 30 лет.
#
# **Рекомендации**
#
# Исходя из потенциальных признаков оттока - критическим периодом для принятия решения является окончание срока действия абонемента сроком на 1 месяц.
#
#  - С учетом того, что клиенты, заключившие долгосрочные контракты, в перспективе уходят гораздо реже - рекомендована организация акций со скидкой при продлении месячного абонемента, особенно на долгосрочной основе, а также абонементы без ограничения количества посещений в неделю (помним про высокую частоту посещений в лояльных группах)
#
#  - Организация привлечения клиентов из числа партнеров финтес-центра, которые также дают хорошее удержание (длительный срок контракта).
